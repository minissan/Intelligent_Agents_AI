# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics import roc_auc_score
np.random.seed(42)
# Load normal and anomalous logs from text files
normal_log = np.loadtxt('log_normal_pioneer.txt')
anomalous_log = np.loadtxt('log_anomalous_pioneer.txt')

normal_log_test = np.loadtxt('log_normal_pioneer_test.txt')
anomalous_log_test = np.loadtxt('log_anomalous_pioneer_test.txt')

normal_log = normal_log[~np.isnan(normal_log).any(axis=1)]
normal_log = normal_log[np.isfinite(normal_log).all(axis=1)]

anomalous_log = anomalous_log[~np.isnan(anomalous_log).any(axis=1)]
anomalous_log = anomalous_log[np.isfinite(anomalous_log).all(axis=1)]

normal_log_test = normal_log_test[~np.isnan(normal_log_test).any(axis=1)]
normal_log_test = normal_log_test[np.isfinite(normal_log_test).all(axis=1)]

anomalous_log_test = anomalous_log_test[~np.isnan(anomalous_log_test).any(axis=1)]
anomalous_log_test = anomalous_log_test[np.isfinite(anomalous_log_test).all(axis=1)]


# Combine the logs and add labels (0 for normal, 1 for anomalous)

logs = np.concatenate((normal_log, anomalous_log), axis=0)
labels = np.concatenate((np.zeros(len(normal_log)), np.ones(len(anomalous_log))))

logs_test = np.concatenate((normal_log_test, anomalous_log_test), axis=0)
labels_test = np.concatenate((np.zeros(len(normal_log_test)), np.ones(len(anomalous_log_test))))

# Split the data into training and testing sets
train_data, _, train_labels, _ = train_test_split(logs, labels, test_size=0.2,random_state=42)

_, test_data, _, test_labels = train_test_split(logs_test, labels_test, test_size=0.5,random_state=42)

scaler = MinMaxScaler()

train_data_scaled = scaler.fit_transform(train_data)
test_data_scaled = scaler.transform(test_data)

# %%
logs.shape
# Out:
# (362, 27)

# %%
#LR

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np
roc_scores = []
num_iterations = 10
classification_reports = []
precisions = []
recalls = []
f1s = []
accuracies=[]

for i in range(num_iterations):
    # Train a logistic regression model
    lr = LogisticRegression(max_iter=1000)
    lr.fit(train_data_scaled, train_labels)

    # Predict on the test set and compute accuracy
    pred_labels = lr.predict(test_data_scaled)
    # Get indices of anomalous instances
    anomaly_indices = np.where(pred_labels == 1)[0]
    # Evaluate the model's performance
    report = classification_report(test_labels, pred_labels, digits=4, output_dict=True)
    classification_reports.append(report)
    roc_score = roc_auc_score(test_labels, pred_labels)
    
    roc_scores.append(roc_score)
    precisions.append(report['weighted avg']['precision'])
    recalls.append(report['weighted avg']['recall'])
    f1s.append(report['weighted avg']['f1-score'])
    accuracies.append(report['accuracy'])

# Calculate average metrics
avg_precision = np.mean(precisions)
avg_recall = np.mean(recalls)
avg_f1 = np.mean(f1s)
avg_accuracy = np.mean(accuracies)
avg_roc_score = np.mean(roc_scores)

print(f'Average ROC score: {avg_roc_score:.4f}')
print(f'Average precision: {avg_precision:.4f}')
print(f'Average recall: {avg_recall:.4f}')
print(f'Average Accuracy: {avg_accuracy:.4f}')

print(f'Average F1-score: {avg_f1:.4f}')
# Out:
# Average ROC score: 0.7490
# Average precision: 0.7804
# Average recall: 0.7736
# Average Accuracy: 0.7736
# Average F1-score: 0.7660

# %%
#SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np

num_iterations = 10
classification_reports = []
precisions = []
recalls = []
f1s = []
accuracies=[]
roc_scores = []

for i in range(num_iterations):
    # Create a SVM classifier with a linear kernel
    svm = SVC(kernel='linear')

    # Train the classifier on the training data
    svm.fit(train_data_scaled, train_labels)

    # Make predictions on the testing data
    pred_labels = svm.predict(test_data_scaled)

    # Evaluate the model's performance
    report = classification_report(test_labels, pred_labels, digits=4, output_dict=True)
    classification_reports.append(report)
    roc_score = roc_auc_score(test_labels, pred_labels)
    
    roc_scores.append(roc_score)
    precisions.append(report['weighted avg']['precision'])
    recalls.append(report['weighted avg']['recall'])
    f1s.append(report['weighted avg']['f1-score'])
    accuracies.append(report['accuracy'])

# Calculate average metrics
avg_precision = np.mean(precisions)
avg_recall = np.mean(recalls)
avg_f1 = np.mean(f1s)
avg_accuracy = np.mean(accuracies)
avg_roc_score = np.mean(roc_scores)

print(f'Average ROC score: {avg_roc_score:.4f}')
print(f'Average precision: {avg_precision:.4f}')
print(f'Average recall: {avg_recall:.4f}')
print(f'Average Accuracy: {avg_accuracy:.4f}')

print(f'Average F1-score: {avg_f1:.4f}')
# Out:
# Average ROC score: 0.7308
# Average precision: 0.7435
# Average recall: 0.7453
# Average Accuracy: 0.7453
# Average F1-score: 0.7427

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Calculate FPR and TPR at different thresholds
fpr_lr, tpr_lr, thresholds_lr = roc_curve(test_labels, lr.predict(test_data_scaled))
fpr_svm, tpr_svm, thresholds_svm = roc_curve(test_labels, svm.predict(test_data_scaled))
fpr_ae, tpr_ae, thresholds_ae = roc_curve(test_labels, anomalies)
# Plot the ROC curve
plt.figure()

plt.plot(fpr_lr, tpr_lr, label='Logistic Regression')
plt.plot(fpr_svm, tpr_svm, label='Support Vector Machine')
plt.plot(fpr_ae, tpr_ae, label='Autoencoder')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')

plt.legend()
plt.savefig('roc-compare-pioneer.pdf')
plt.show()

# %%
#OC-SVM

# %%
from sklearn.svm import OneClassSVM
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np

num_iterations = 10

classification_reports = []
precisions = []
recalls = []
f1s = []
accuracies=[]

for i in range(num_iterations):
    clf = OneClassSVM()  # nu is a hyperparameter between 0 and 1
    clf.fit(train_data_scaled)

    # Predict on the test set
    pred_labels = clf.predict(test_data_scaled)
    pred_labels[pred_labels == 1] = 0  # convert predicted labels from 1 to 0
    pred_labels[pred_labels == -1] = 1  # convert predicted labels from -1 to 1
    
     # Evaluate the model's performance
    report = classification_report(test_labels, pred_labels, digits=4, output_dict=True)
    classification_reports.append(report)
    
    precisions.append(report['weighted avg']['precision'])
    recalls.append(report['weighted avg']['recall'])
    f1s.append(report['weighted avg']['f1-score'])
    accuracies.append(report['accuracy'])

# Calculate average metrics
avg_precision = np.mean(precisions)
avg_recall = np.mean(recalls)
avg_f1 = np.mean(f1s)
avg_accuracy = np.mean(accuracies)

print(f'Average precision: {avg_precision:.4f}')
print(f'Average recall: {avg_recall:.4f}')
print(f'Average Accuracy: {avg_accuracy:.4f}')

print(f'Average F1-score: {avg_f1:.4f}')
# Out:
# Average precision: 0.6530
# Average recall: 0.5849
# Average Accuracy: 0.5849
# Average F1-score: 0.5734

# %%
from sklearn.metrics import classification_report
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
import numpy as np

num_iterations = 10
thresholds = []
classification_reports = []
precisions = []
recalls = []
f1s = []
accuracies=[]
roc_scores = []
for i in range(num_iterations):
    normal_train_data = train_data_scaled[train_labels == 0]

    # Define the autoencoder model
    input_dim = train_data_scaled.shape[1]
    encoding_dim = 16

    input_layer = Input(shape=(input_dim,))
    encoder = Dense(encoding_dim, activation="relu")(input_layer)
    encoder = Dense(encoding_dim // 2, activation="relu")(encoder)
    decoder = Dense(encoding_dim, activation="relu")(encoder)
    decoder = Dense(input_dim, activation="relu")(decoder)

    autoencoder = Model(inputs=input_layer, outputs=decoder)

    # Compile and fit the model
    autoencoder.compile(optimizer='adam', loss='mean_squared_error')
    autoencoder.fit(normal_train_data, normal_train_data, epochs=50, batch_size=32)

    # Get reconstruction error on the training data
    train_predictions = autoencoder.predict(normal_train_data)
    mse_train = np.mean(np.power(normal_train_data - train_predictions, 2), axis=1)

    # Set the threshold as the maximum reconstruction error in the training data
    threshold = np.max(mse_train) 
    thresholds.append(threshold)

    # Get reconstruction error on the test data
    test_predictions = autoencoder.predict(test_data_scaled)
    mse_test = np.mean(np.power(test_data_scaled - test_predictions, 2), axis=1)

    # Detect anomalies in the test data
    anomalies = mse_test > threshold

    # Evaluate the model's performance
    report = classification_report(test_labels, anomalies, digits=4, output_dict=True)
    classification_reports.append(report)
    roc_score = roc_auc_score(test_labels, anomalies)
    
    roc_scores.append(roc_score)
    precisions.append(report['weighted avg']['precision'])
    recalls.append(report['weighted avg']['recall'])
    f1s.append(report['weighted avg']['f1-score'])
    accuracies.append(report['accuracy'])

# Calculate average metrics
avg_precision = np.mean(precisions)
avg_recall = np.mean(recalls)
avg_f1 = np.mean(f1s)
avg_accuracy = np.mean(accuracies)
avg_roc_score = np.mean(roc_scores)

print(f'Average ROC score: {avg_roc_score:.4f}')
print(f'Average precision: {avg_precision:.4f}')
print(f'Average recall: {avg_recall:.4f}')
print(f'Average Accuracy: {avg_accuracy:.4f}')

print(f'Average F1-score: {avg_f1:.4f}')
# Out:
# Epoch 1/50
# 9/9 [==============================] - 2s 5ms/step - loss: 0.2157
# Epoch 2/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1768
# Epoch 3/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1457
# Epoch 4/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1255
# Epoch 5/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1107
# Epoch 6/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1030
# Epoch 7/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0992
# Epoch 8/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0973
# Epoch 9/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0961
# Epoch 10/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0954
# Epoch 11/50
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0947
# Epoch 12/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0940
# Epoch 13/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0934
# Epoch 14/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0928
# Epoch 15/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0921
# Epoch 16/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0915
# Epoch 17/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0908
# Epoch 18/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0900
# Epoch 19/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0893
# Epoch 20/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0884
# Epoch 21/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0876
# Epoch 22/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0868
# Epoch 23/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0859
# Epoch 24/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0850
# Epoch 25/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0840
# Epoch 26/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0830
# Epoch 27/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0820
# Epoch 28/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0810
# Epoch 29/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0802
# Epoch 30/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0792
# Epoch 31/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0747
# Epoch 32/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0708
# Epoch 33/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0702
# Epoch 34/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0693
# Epoch 35/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0686
# Epoch 36/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0680
# Epoch 37/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0674
# Epoch 38/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0668
# Epoch 39/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0663
# Epoch 40/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0657
# Epoch 41/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0651
# Epoch 42/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0646
# Epoch 43/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0640
# Epoch 44/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0634
# Epoch 45/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0627
# Epoch 46/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0622
# Epoch 47/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0617
# Epoch 48/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0612
# Epoch 49/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0606
# Epoch 50/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0601
# 9/9 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 6ms/step
# Epoch 1/50
# 9/9 [==============================] - 2s 4ms/step - loss: 0.2366
# Epoch 2/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1996
# Epoch 3/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1675
# Epoch 4/50
# 9/9 [==============================] - 0s 1ms/step - loss: 0.1461
# Epoch 5/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1335
# Epoch 6/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1236
# Epoch 7/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1168
# Epoch 8/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1128
# Epoch 9/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1103
# Epoch 10/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1090
# Epoch 11/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1083
# Epoch 12/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1077
# Epoch 13/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1072
# Epoch 14/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1067
# Epoch 15/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1063
# Epoch 16/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1059
# Epoch 17/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1054
# Epoch 18/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1050
# Epoch 19/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1045
# Epoch 20/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1041
# Epoch 21/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1035
# Epoch 22/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1030
# Epoch 23/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1025
# Epoch 24/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1020
# Epoch 25/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1015
# Epoch 26/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1011
# Epoch 27/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1006
# Epoch 28/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1002
# Epoch 29/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0999
# Epoch 30/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0995
# Epoch 31/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0992
# Epoch 32/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0989
# Epoch 33/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0985
# Epoch 34/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0981
# Epoch 35/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0976
# Epoch 36/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0960
# Epoch 37/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0955
# Epoch 38/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0951
# Epoch 39/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0948
# Epoch 40/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0944
# Epoch 41/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0941
# Epoch 42/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0938
# Epoch 43/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0935
# Epoch 44/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0932
# Epoch 45/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0930
# Epoch 46/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0927
# Epoch 47/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0924
# Epoch 48/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0921
# Epoch 49/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0919
# Epoch 50/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0916
# 9/9 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 3ms/step
# Epoch 1/50
# 9/9 [==============================] - 2s 4ms/step - loss: 0.2544
# Epoch 2/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2219
# Epoch 3/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1890
# Epoch 4/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1691
# Epoch 5/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1627
# Epoch 6/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1566
# Epoch 7/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1523
# Epoch 8/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1466
# Epoch 9/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1383
# Epoch 10/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1321
# Epoch 11/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1278
# Epoch 12/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1246
# Epoch 13/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1226
# Epoch 14/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1215
# Epoch 15/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1207
# Epoch 16/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1199
# Epoch 17/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1192
# Epoch 18/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1186
# Epoch 19/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1180
# Epoch 20/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1175
# Epoch 21/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1170
# Epoch 22/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1163
# Epoch 23/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1145
# Epoch 24/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1104
# Epoch 25/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1055
# Epoch 26/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1007
# Epoch 27/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0946
# Epoch 28/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0898
# Epoch 29/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0873
# Epoch 30/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0860
# Epoch 31/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0852
# Epoch 32/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0846
# Epoch 33/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0841
# Epoch 34/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0836
# Epoch 35/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0832
# Epoch 36/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0828
# Epoch 37/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0823
# Epoch 38/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0819
# Epoch 39/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0816
# Epoch 40/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0813
# Epoch 41/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0810
# Epoch 42/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0807
# Epoch 43/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0804
# Epoch 44/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0802
# Epoch 45/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0799
# Epoch 46/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0797
# Epoch 47/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0794
# Epoch 48/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0792
# Epoch 49/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0790
# Epoch 50/50
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0788
# 9/9 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 2ms/step
# Epoch 1/50
# 9/9 [==============================] - 2s 4ms/step - loss: 0.2567
# Epoch 2/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2336
# Epoch 3/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2121
# Epoch 4/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1940
# Epoch 5/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1797
# Epoch 6/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1702
# Epoch 7/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1647
# Epoch 8/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1613
# Epoch 9/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1592
# Epoch 10/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1579
# Epoch 11/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1570
# Epoch 12/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1563
# Epoch 13/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1557
# Epoch 14/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1540
# Epoch 15/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1491
# Epoch 16/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1456
# Epoch 17/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1439
# Epoch 18/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1431
# Epoch 19/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1425
# Epoch 20/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1418
# Epoch 21/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1412
# Epoch 22/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1406
# Epoch 23/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1399
# Epoch 24/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1394
# Epoch 25/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1388
# Epoch 26/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1382
# Epoch 27/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1375
# Epoch 28/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1361
# Epoch 29/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1351
# Epoch 30/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1344
# Epoch 31/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1337
# Epoch 32/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1331
# Epoch 33/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1325
# Epoch 34/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1319
# Epoch 35/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1313
# Epoch 36/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1308
# Epoch 37/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1302
# Epoch 38/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1297
# Epoch 39/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1292
# Epoch 40/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1287
# Epoch 41/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1283
# Epoch 42/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1278
# Epoch 43/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1275
# Epoch 44/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1272
# Epoch 45/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1267
# Epoch 46/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1263
# Epoch 47/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1260
# Epoch 48/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1257
# Epoch 49/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1255
# Epoch 50/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1252
# 9/9 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 3ms/step
# Epoch 1/50
# 9/9 [==============================] - 2s 2ms/step - loss: 0.2510
# Epoch 2/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2127
# Epoch 3/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1773
# Epoch 4/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1537
# Epoch 5/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1385
# Epoch 6/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1257
# Epoch 7/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1164
# Epoch 8/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1104
# Epoch 9/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1070
# Epoch 10/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1052
# Epoch 11/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1043
# Epoch 12/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1037
# Epoch 13/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1032
# Epoch 14/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1028
# Epoch 15/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1024
# Epoch 16/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1020
# Epoch 17/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1016
# Epoch 18/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1012
# Epoch 19/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1007
# Epoch 20/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1003
# Epoch 21/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0999
# Epoch 22/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0993
# Epoch 23/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0988
# Epoch 24/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0983
# Epoch 25/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0978
# Epoch 26/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0973
# Epoch 27/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0968
# Epoch 28/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0964
# Epoch 29/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0959
# Epoch 30/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0955
# Epoch 31/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0950
# Epoch 32/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0946
# Epoch 33/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0923
# Epoch 34/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0870
# Epoch 35/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0840
# Epoch 36/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0800
# Epoch 37/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0733
# Epoch 38/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0701
# Epoch 39/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0692
# Epoch 40/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0690
# Epoch 41/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0687
# Epoch 42/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0683
# Epoch 43/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0679
# Epoch 44/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0677
# Epoch 45/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0674
# Epoch 46/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0671
# Epoch 47/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0668
# Epoch 48/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0664
# Epoch 49/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0659
# Epoch 50/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0654
# 9/9 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 5ms/step
# Epoch 1/50
# 9/9 [==============================] - 2s 4ms/step - loss: 0.2610
# Epoch 2/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2320
# Epoch 3/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2030
# Epoch 4/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1763
# Epoch 5/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1560
# Epoch 6/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1424
# Epoch 7/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1298
# Epoch 8/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1171
# Epoch 9/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1094
# Epoch 10/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1056
# Epoch 11/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1039
# Epoch 12/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1030
# Epoch 13/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1024
# Epoch 14/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1021
# Epoch 15/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1018
# Epoch 16/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1015
# Epoch 17/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1013
# Epoch 18/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1010
# Epoch 19/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1008
# Epoch 20/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1006
# Epoch 21/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1004
# Epoch 22/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1002
# Epoch 23/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1000
# Epoch 24/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0998
# Epoch 25/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0996
# Epoch 26/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0994
# Epoch 27/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0992
# Epoch 28/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0990
# Epoch 29/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0988
# Epoch 30/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0986
# Epoch 31/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0984
# Epoch 32/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0983
# Epoch 33/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0981
# Epoch 34/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0978
# Epoch 35/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0976
# Epoch 36/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0973
# Epoch 37/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0971
# Epoch 38/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0968
# Epoch 39/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0965
# Epoch 40/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0963
# Epoch 41/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0960
# Epoch 42/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0957
# Epoch 43/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0954
# Epoch 44/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0951
# Epoch 45/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0948
# Epoch 46/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0945
# Epoch 47/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0941
# Epoch 48/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0939
# Epoch 49/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0935
# Epoch 50/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0931
# 9/9 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 3ms/step
# Epoch 1/50
# 9/9 [==============================] - 2s 4ms/step - loss: 0.2656
# Epoch 2/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2324
# Epoch 3/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1958
# Epoch 4/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1612
# Epoch 5/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1356
# Epoch 6/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1167
# Epoch 7/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1070
# Epoch 8/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1019
# Epoch 9/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0995
# Epoch 10/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0981
# Epoch 11/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0976
# Epoch 12/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0971
# Epoch 13/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0968
# Epoch 14/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0965
# Epoch 15/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0962
# Epoch 16/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0959
# Epoch 17/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0957
# Epoch 18/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0953
# Epoch 19/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0951
# Epoch 20/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0948
# Epoch 21/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0945
# Epoch 22/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0942
# Epoch 23/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0939
# Epoch 24/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0936
# Epoch 25/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0932
# Epoch 26/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0927
# Epoch 27/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0922
# Epoch 28/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0918
# Epoch 29/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0912
# Epoch 30/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0907
# Epoch 31/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0899
# Epoch 32/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0891
# Epoch 33/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0884
# Epoch 34/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0856
# Epoch 35/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0737
# Epoch 36/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0700
# Epoch 37/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0694
# Epoch 38/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0684
# Epoch 39/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0680
# Epoch 40/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0675
# Epoch 41/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0672
# Epoch 42/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0668
# Epoch 43/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0662
# Epoch 44/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0648
# Epoch 45/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0639
# Epoch 46/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0624
# Epoch 47/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0615
# Epoch 48/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0608
# Epoch 49/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0603
# Epoch 50/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0599
# 9/9 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 3ms/step
# Epoch 1/50
# 9/9 [==============================] - 2s 2ms/step - loss: 0.2838
# Epoch 2/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2576
# Epoch 3/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2275
# Epoch 4/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1997
# Epoch 5/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1803
# Epoch 6/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1694
# Epoch 7/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1624
# Epoch 8/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1581
# Epoch 9/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1561
# Epoch 10/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1549
# Epoch 11/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1542
# Epoch 12/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1537
# Epoch 13/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1533
# Epoch 14/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1529
# Epoch 15/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1526
# Epoch 16/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1522
# Epoch 17/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1517
# Epoch 18/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1513
# Epoch 19/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1509
# Epoch 20/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1505
# Epoch 21/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1502
# Epoch 22/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1498
# Epoch 23/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1495
# Epoch 24/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1493
# Epoch 25/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1491
# Epoch 26/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1489
# Epoch 27/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1486
# Epoch 28/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1484
# Epoch 29/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1482
# Epoch 30/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1480
# Epoch 31/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1478
# Epoch 32/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1476
# Epoch 33/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1475
# Epoch 34/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1473
# Epoch 35/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1471
# Epoch 36/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1469
# Epoch 37/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1467
# Epoch 38/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1465
# Epoch 39/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1464
# Epoch 40/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1462
# Epoch 41/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1460
# Epoch 42/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1458
# Epoch 43/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1455
# Epoch 44/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1451
# Epoch 45/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1446
# Epoch 46/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1441
# Epoch 47/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1435
# Epoch 48/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1429
# Epoch 49/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1423
# Epoch 50/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1410
# 9/9 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 859us/step
# Epoch 1/50
# 9/9 [==============================] - 2s 2ms/step - loss: 0.2625
# Epoch 2/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2436
# Epoch 3/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2247
# Epoch 4/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2099
# Epoch 5/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1928
# Epoch 6/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1743
# Epoch 7/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1595
# Epoch 8/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1463
# Epoch 9/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1354
# Epoch 10/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1282
# Epoch 11/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1238
# Epoch 12/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1211
# Epoch 13/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1196
# Epoch 14/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1188
# Epoch 15/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1182
# Epoch 16/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1178
# Epoch 17/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1174
# Epoch 18/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1171
# Epoch 19/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1167
# Epoch 20/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1162
# Epoch 21/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1158
# Epoch 22/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1155
# Epoch 23/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1149
# Epoch 24/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1126
# Epoch 25/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1065
# Epoch 26/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1037
# Epoch 27/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1027
# Epoch 28/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1021
# Epoch 29/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1013
# Epoch 30/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1006
# Epoch 31/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0997
# Epoch 32/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0962
# Epoch 33/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0899
# Epoch 34/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0834
# Epoch 35/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0812
# Epoch 36/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0804
# Epoch 37/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0796
# Epoch 38/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0787
# Epoch 39/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0780
# Epoch 40/50
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0772
# Epoch 41/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0766
# Epoch 42/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0758
# Epoch 43/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0752
# Epoch 44/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0745
# Epoch 45/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0740
# Epoch 46/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0735
# Epoch 47/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0730
# Epoch 48/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0725
# Epoch 49/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0720
# Epoch 50/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0716
# 9/9 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 5ms/step
# Epoch 1/50
# 9/9 [==============================] - 3s 3ms/step - loss: 0.2539
# Epoch 2/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2203
# Epoch 3/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1813
# Epoch 4/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1557
# Epoch 5/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1360
# Epoch 6/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1217
# Epoch 7/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1130
# Epoch 8/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1080
# Epoch 9/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1050
# Epoch 10/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1032
# Epoch 11/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1022
# Epoch 12/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1015
# Epoch 13/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1011
# Epoch 14/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1008
# Epoch 15/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1005
# Epoch 16/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1003
# Epoch 17/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1001
# Epoch 18/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0998
# Epoch 19/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0996
# Epoch 20/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0993
# Epoch 21/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0992
# Epoch 22/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0990
# Epoch 23/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0987
# Epoch 24/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0985
# Epoch 25/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0983
# Epoch 26/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0980
# Epoch 27/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0978
# Epoch 28/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0975
# Epoch 29/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0973
# Epoch 30/50
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0971
# Epoch 31/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0968
# Epoch 32/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0967
# Epoch 33/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0965
# Epoch 34/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0962
# Epoch 35/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0960
# Epoch 36/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0959
# Epoch 37/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0957
# Epoch 38/50
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0955
# Epoch 39/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0954
# Epoch 40/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0952
# Epoch 41/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0950
# Epoch 42/50
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0949
# Epoch 43/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0948
# Epoch 44/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0947
# Epoch 45/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0946
# Epoch 46/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0943
# Epoch 47/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0942
# Epoch 48/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0941
# Epoch 49/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0940
# Epoch 50/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0939
# 9/9 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 4ms/step
# Average ROC score: 0.7675
# Average precision: 0.8488
# Average recall: 0.8038
# Average Accuracy: 0.8038
# Average F1-score: 0.7888

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load normal and anomalous logs
normal_log = np.loadtxt('log_normal_pioneer.txt', skiprows=1)
anomalous_log = np.loadtxt('log_anomalous_pioneer.txt', skiprows=1)

# Plot position in x, y, and z dimensions for normal and anomalous logs side-by-side
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
axs[0].plot(normal_log[:, 1], normal_log[:, 2], label='Normal')
axs[0].plot(anomalous_log[:, 1], anomalous_log[:, 2], label='Anomalous')
axs[0].set_xlabel('x position')
axs[0].set_ylabel('y position')
axs[0].legend()

axs[1].plot(normal_log[:, 1], normal_log[:, 3], label='Normal')
axs[1].plot(anomalous_log[:, 1], anomalous_log[:, 3], label='Anomalous')
axs[1].set_xlabel('x position')
axs[1].set_ylabel('z position')
axs[1].legend()

axs[2].plot(normal_log[:, 2], normal_log[:, 3], label='Normal')
axs[2].plot(anomalous_log[:, 2], anomalous_log[:, 3], label='Anomalous')
axs[2].set_xlabel('y position')
axs[2].set_ylabel('z position')
axs[2].legend()
plt.savefig('x-y-z-plot.jpg')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

normal_data = pd.read_csv('log_normal.txt', delim_whitespace=True)
anomalous_data = pd.read_csv('log_anomalous.txt', delim_whitespace=True)
# Load the normal and anomalous log files into separate pandas dataframes



normal_data = normal_data[~np.isnan(normal_data).any(axis=1)]
normal_data = normal_data[np.isfinite(normal_data).all(axis=1)]

anomalous_data = anomalous_data[~np.isnan(anomalous_data).any(axis=1)]
anomalous_data = anomalous_data[np.isfinite(anomalous_data).all(axis=1)]

# Combine the two dataframes into one
data = pd.concat([normal_data, anomalous_data])

# Create a numpy array from the combined dataframe
X = data.to_numpy()

# Create labels for the data points (0 for normal, 1 for anomalous)
y = np.concatenate([np.zeros(len(normal_data)), np.ones(len(anomalous_data))])

# Apply t-SNE to reduce the dimensionality of the data to 2 dimensions
X_tsne = TSNE(n_components=2, random_state=42).fit_transform(X)

# Plot the t-SNE results with different colors for the two clusters
plt.scatter(X_tsne[:, 0][y==0], X_tsne[:, 1][y==0], c='blue', label='normal')
plt.scatter(X_tsne[:, 0][y==1], X_tsne[:, 1][y==1], c='red', label='anomalous')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load normal and anomalous logs
normal_log = np.loadtxt('log_normal.txt', skiprows=1)
anomalous_log = np.loadtxt('log_anomalous.txt', skiprows=1)

# Plot position in x, y, and z dimensions for normal and anomalous logs
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot(projection='3d')
ax.plot(normal_log[:, 1], normal_log[:, 2], normal_log[:, 3], label='Normal')
ax.plot(anomalous_log[:, 1], anomalous_log[:, 2], anomalous_log[:, 3], label='Anomalous')
ax.set_xlabel('x position')
ax.set_ylabel('y position')
ax.set_zlabel('z position')
ax.legend()
plt.savefig('x-y-z-plot.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load normal and anomalous logs
normal_log = np.loadtxt('log_normal_pioneer_test.txt', skiprows=1)
anomalous_log = np.loadtxt('log_anomalous_pioneer_test.txt', skiprows=1)

# Plot acc for normal and anomalous logs
plt.figure(figsize=(6, 4))
plt.plot(normal_log[:, 0], normal_log[:, 17], label='Normal')
plt.plot(anomalous_log[:, 0], anomalous_log[:, 17], label='Anomalous')
plt.xlabel('Simulation Time')
plt.ylabel('Acceleration')
plt.legend()
plt.savefig('acceleration-plot-pioneer.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Load normal and anomalous logs
normal_log = np.loadtxt('log_normal_pioneer_test.txt', skiprows=1)
anomalous_log = np.loadtxt('log_anomalous_pioneer_test.txt', skiprows=1)

# Plot acc for normal and anomalous logs
plt.figure(figsize=(6, 4))
plt.plot(normal_log[:, 0], normal_log[:, 17], label='Normal')
plt.plot(anomalous_log[:, 0], anomalous_log[:, 17], label='Anomalous')

# Mark detected anomalies
plt.scatter(anomalous_log[anomaly_indices, 0], anomalous_log[anomaly_indices, 17], marker='x', color='red', label='Detected Anomalies')


plt.xlabel('Simulation Time')
plt.ylabel('Acceleration')
plt.legend()
plt.savefig('acceleration-plot_pioneer.pdf')
plt.show()
